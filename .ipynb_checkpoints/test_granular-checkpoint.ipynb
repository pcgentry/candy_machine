# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-bright')

from scipy.stats import norm, skewnorm, skew
from src.simulation import Simulation
from src.machine import Machine

from helpers import *

num_simulations=50
num_simulations=30

# %%
strategy="random"
machine_object = Machine(strategy=strategy)
_, _ = run_strat(machine_object=machine_object, num_simulations=num_simulations, x_lims = (15, 25))

print(f"Model trainings: {machine_object.model.trainings}")
print(f"Model saves: {machine_object.saves}")
# Out:
# <class 'src.machine.Machine'>
# Model trainings: 0
# Model saves: 676

# %%
strategy="decision_tree"
machine_object = Machine(strategy=strategy)
_, _ = run_strat(machine_object=machine_object, num_simulations=num_simulations, x_lims = (15, 25))

print(f"Model trainings: {machine_object.model.trainings}")
print(f"Model saves: {machine_object.saves}")
# Out:
# <class 'src.machine.Machine'>
# Model trainings: 88939
# Model saves: 532

# %%
# strategy="BernoulliNB"
# machine_object = Machine(strategy=strategy)
# _, _ = run_strat(machine_object=machine_object, num_simulations=num_simulations, x_lims = (16, 24))

# print(f"Model trainings: {machine_object.model.trainings}")
# print(f"Model saves: {machine_object.saves}")
