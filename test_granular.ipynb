# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-bright')

from scipy.stats import norm, skewnorm, skew
from src.simulation import Simulation
from helpers import *

# %%
run_strat(strategy="random", num_simulations=5)

# %%
run_strat(strategy="decision_tree", num_simulations=5)

# %%
run_strat(strategy="BernoulliNB", num_simulations=5)
